# %%
import logging

logger1 = logging.getLogger("module 1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module 2")
logger2.setLevel(logging.WARNING)

import logging

logging.basicConfig(#previously I have done the app.log setting so it wont work so you have to restart the kernel
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
logger1.debug("this is debug message")
logger1.info("this is an info message")
logger2.warning("warning")
logger2.error("error")
logger2.critical("critical")
# Out:
# 2025-02-04 22:56:59-module 1-DEBUG-this is debug message
# 2025-02-04 22:56:59-module 1-INFO-this is an info message
# 2025-02-04 22:56:59-module 2-WARNING-warning
# 2025-02-04 22:56:59-module 2-ERROR-error
# 2025-02-04 22:56:59-module 2-CRITICAL-critical
